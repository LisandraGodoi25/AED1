# %%
x = 10
y = 3

x = ((3*y) / (5 * y + 7) + (2 * y))

print(x)
# Out:
# 6.409090909090909

# %% [markdown]
# Calcular a área de um quadrilátero de 2 lados iguais
# Leia 2 inteiros, fale os valores lidos e a área calculada

# %%
a = float(input("Insira o primeiro lado: "))
b = float(input("Insira o segundo lado:  "))
