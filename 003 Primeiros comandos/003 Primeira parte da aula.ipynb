# %% [markdown]
# # Para chegar até o Anaconda Local Host
#
# cd Alunos
#
# cd Desktop
#
# cd foldername
#
# jupyter notebook

# %%
erro = print("O intellicode está dando erro")
# Out:
# O intellicode está dando erro

# %%
# Comentário de uma linha
from random import randint

print("real code")

'''
Comentário de várias linhas

uuuuuuu'''

print("A second real code")
# Out:
# real code
# A second real code

# %%
print(f"INT: 6 + 5 = {6+5} ")
print(f"STR: 6 + 5 = {'6'+'5'} ")
# Out:
# INT: 6 + 5 = 11
# STR: 6 + 5 = 65

# %%
nome = "Lys"
type(nome)
# Out:
# str

# %% [markdown]
# # DIVISÃO
#
# Normal: 7/2

# %%
print(7/2)
# Out:
# 3.5

# %% [markdown]
# Parte inteira: 7//2

# %%
print(7//2)
# Out:
# 3

# %% [markdown]
# Resto da divisão: 7%2

# %%
print(7%2)
# Out:
# 1
