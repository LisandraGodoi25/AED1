# %%
print("Hello Mundo")
# Out:
# Hello Mundo

# %% [markdown]
# # Hello World!!
#
# I am here again studying python! I am really excited to learn more, as much as I am NOT that excited to start from the scratch

# %%
print("test")
# Out:
# test

# %%
name = input("Qual o seu nome?")
# Out:
# Qual o seu nome? Lisandra
