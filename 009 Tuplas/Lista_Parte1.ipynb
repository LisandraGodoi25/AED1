# %% [markdown]
# # Lista de exercícios AED1 - Parte 1

# %% [markdown]
# ### Exercício 0 - Faça um algoritmo para ler um número e mostrar se ele é par ou impar, positivo ou negativo.

# %%
num = int(input("Insira um número inteiro: "))

if num % 2 == 0 and num > 0:
    print(f"{num} é um número par e positivo")

elif num % 2 == 0 and num < 0:
    print(f"{num} é um número par e negativo")

elif num % 2 != 0 and num > 0:
    print(f"{num} é um número impar e positivo")

elif num % 2 != 0 and num < 0:
    print(f"{num} é um número impar e negativo")

# %% [markdown]
# ### Exercício 1 - Faça um Programa que peça dois números e imprima o maior deles.

# %%
num1 = float(input("Insira o primeiro número: "))

num2 = float(input("Insira o segundo número: "))

if num1 >= num2:
    print(f"{num1}")

elif num2 > num1:
    print(f"{num2}")

# %% [markdown]
# ### Exercício 2 - Faça um Programa que peça um valor e mostre na tela se o valor é positivo ou negativo.

# %%
num = int(input("Insira um número: "))

if num > 0:
    print(f"{num} é positivo")
elif num < 0:
    print(f"{num} é negativo")

# %% [markdown]
# ### Exercício 3 - Faça um Programa que verifique se uma letra digitada é vogal ou consoante.

# %%
vowel = ("a", "e", "i", "o", "u")

letter = input("Insira uma letra: ").lower()
notvowel = 0

for vogal in vowel:
    if vogal == letter:
        print("VOGAL")
    notvowel += 1

if notvowel == 5:
    print("CONSOANTE")

# %% [markdown]
# ### Exercício 4 - Faça um programa para a leitura de duas notas parciais de um aluno. O programa deve calcular a média alcançada por aluno e apresentar:
# ##### a. A mensagem "Aprovado", se a média alcançada for maior ou igual a sete;
# ##### b. A mensagem "Reprovado", se a média for menor do que sete;
# ##### c. A mensagem "Aprovado com Distinção", se a média for igual a dez.

# %%
nota1 = float(input("Insira a primeira nota: "))
nota2 = float(input("Insira a segunda nota: "))

media = (nota1 + nota2)/2

if media == 10:
    print("Aprovado com Distinção")
elif media < 10 and media >= 7:
    print("Aprovado")
elif media < 7:
    print("Reprovado")

# %% [markdown]
# ### Exercício 5 - Faça um programa que pergunte o preço de três produtos e informe qual produto você deve comprar, sabendo que a decisão é sempre pelo mais barato.

# %%
prod1 = float(input("Insira o preço do primeiro produto: "))
prod2 = float(input("Insira o preço do segundo produto: "))

if prod1 <= prod2:
    parcial = prod1
    aparcial = "produto 1"
else:
    parcial = prod2
    aparcial = "produto 2"

print(f"primeira parcial: {parcial}")

prod3 = float(input("Insira o preço do terceiro produto: "))

if prod3 < parcial:
    parcial = prod3
    aparcial = "produto 3"
print(f"segunda parcial: {parcial}")

print(f"Você deveria comprar o {aparcial}, que custa {parcial}")

# %% [markdown]
# ### Exercício 6 - Faça um Programa que leia três números e mostre-os em ordem decrescente.

# %%
nums = []
num1 = float(input("Insira o preço do primeiro produto: "))
nums.append(num1)
num2 = float(input("Insira o preço do segundo produto: "))
nums.append(num2)
num3 = float(input("Insira o preço do terceiro produto: "))
nums.append(num3)

nums.sort(reverse=True)

print(nums)

# %% [markdown]
# ### Exercício 7 - Faça um Programa que pergunte em que turno você estuda. Peça para digitar M-matutino ou V-Vespertino ou N- Noturno.
# Imprima a mensagem "Bom Dia!", "Boa Tarde!" ou "Boa Noite!" ou "Valor Inválido!", conforme o caso.

# %%
turno = input('''Em que turno você estuda?
      
      Insira:
      M - Matutino
      V - Vespertino
      N - Noturno''')

if turno == "M":
    print("Bom Dia!")
elif turno == "V":
    print("Boa Tarde!")
elif turno == "N":
    print("Boa Noite!")

# %% [markdown]
# ### Exercício 8 - As Organizações Tabajara resolveram dar um aumento de salário aos seus colaboradores e lhe contraram para desenvolver o programa que calculará os reajustes.
# #### a. Faça um programa que recebe o salário de um colaborador e o reajuste segundo o seguinte critério, baseado no  salário atual:
#
# #### b. salários até R$ 280,00 (incluindo) : aumento de 20%
#
# #### c. salários entre R$ 280,00 e R$ 700,00 : aumento de 15%
#
# #### d. salários entre R$ 700,00 e R$ 1500,00 : aumento de 10%
#
# #### e. salários de R$ 1500,00 em diante : aumento de 5% Após o aumento ser realizado, informe na tela:
#
# #### f. o salário antes do reajuste;
#
# #### g. o percentual de aumento aplicado;
#
# #### h. o valor do aumento;
#
# #### i. o novo salário, após o aumento.

# %%
sallary = float(input("Insira seu salário atual: "))

print(f"Seu salário atual é: R${sallary}")

if sallary <= 280:
    araise = "20%"
    sraise = sallary * 0.2
    newsallary = sallary + sraise

elif sallary <= 700:
    araise = "15%"
    sraise = sallary * 0.15
    newsallary = sallary + sraise

elif sallary <= 1500:
    araise = "10%"
    sraise = sallary * 0.1
    newsallary = sallary + sraise

elif sallary > 1500:
    araise = "5%"
    sraise = sallary * 0.05
    newsallary = sallary + sraise



print(f"O porcentual de aumento será de: {araise}")
print(f"O valor nominal do aumento será de: R${sraise}")
print(f"Seu novo salário será: R${newsallary}")

# %% [markdown]
# ### Exercício 9 - Faça um programa para o cálculo de uma folha de pagamento, sabendo que os descontos são do Imposto de Renda, que depende do salário bruto (conforme tabela abaixo) e 3% para o Sindicato e que o FGTS corresponde a 11% do Salário Bruto, mas não é descontado (é a empresa que deposita). O Salário Líquido corresponde ao Salário Bruto menos os descontos. O programa deverá pedir ao usuário o valor da sua hora e a quantidade de horas trabalhadas no mês.

# %% [markdown]
# ##### a. Desconto do IR:
#
# ##### b. Salário Bruto até 900 (inclusive) - isento
#
# ##### c. Salário Bruto até 1500 (inclusive) - desconto de 5%
#
# ##### d. Salário Bruto até 2500 (inclusive) - desconto de 10%
#
# ##### e. Salário Bruto acima de 2500 - desconto de 20% Imprima na tela as informações, dispostas conforme o exemplo
#
# ##### abaixo. No exemplo o valor da hora é 5 e a quantidade de hora é 220

# %%
valorhora = float(input("Insira o valor da sua hora: "))
qnthoras = int(input("Insira o número de horas trabalhadas: "))

bruto = valorhora * qnthoras

sindicato = bruto * 0.03

if bruto <= 900:
    irenda = 0
elif bruto <= 1500:
    irenda = bruto * 0.05
elif bruto <= 2500:
    irenda = bruto * 0.1
elif bruto > 2500:
    irenda = bruto * 0,2

liquido = bruto - sindicato - irenda

texto = "DEMONSTRATIVO SALARIAL"
print(f"{texto:^33}")
print(f"{'':=^33}")
print(f"SALÁRIO BRUTO: R$        {bruto:8.2f}")
print(f"(-) Taxa Sindical: R$    {sindicato:8.2f}")
print(f"(-) Imposto de Renda:R$  {irenda:8.2f}")
print(f"{'':-^33}")
print(f"SALÁRIO LÍQUIDO:R$       {liquido:8.2f}")
# Out:
#      DEMONSTRATIVO SALARIAL
# =================================
# SALÁRIO BRUTO: R$           16.00
# (-) Taxa Sindical: R$        0.48
# (-) Imposto de Renda:R$      0.00
# ---------------------------------
# SALÁRIO LÍQUIDO:R$          15.52

# %% [markdown]
# ### 10 - Faça um programa que lê as duas notas parciais obtidas por um aluno numa disciplina ao longo de um semestre, e calcule
# a sua média. A atribuição de conceitos obedece à tabela abaixo:

# %% [markdown]
# ##### a.   Média de Aproveitamento  Conceito
#
# ##### b.   Entre 9.0 e 10.0        A
#
# ##### c.   Entre 7.5 e 9.0         B
#
# ##### d.   Entre 6.0 e 7.5         C
#
# ##### e.   Entre 4.0 e 6.0         D
#
# ##### f.   Entre 4.0 e zero        E

# %%
nota1 = float(input("Insira a primeira nota: "))
nota2 = float(input("Insira a segunda nota: "))

media = (nota1 + nota2)/2

if media > 9:
    medial = "A"
elif media > 7.5:
    medial = "B"
elif media > 6:
    medial = "C"
elif media > 4:
    medial = "D"
elif media <= 4:
    medial = "E"


print(f"A média será {medial}")
# Out:
# A média será E
