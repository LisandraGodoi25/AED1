# %% [markdown]
# ## **Capítulos 3 - Python Essencial: Curso Rápido para Iniciantes e Profissionais**
#
# ---

# %%
greetings = "Hello World!"
print(greetings)
# Out:
# Hello World!

# %%
firstname = "Dilermando"
print(firstname)
# Out:
# Dilermando

# %%
first_name = "Dilermando"
print(first_name)
# Out:
# Dilermando

# %%
age = 53
first_name = "Dilermando"
last_name = "Piva Jr."
country = "Brazil"
phone_number = 999999999

# %%
age = 53                   #==> int
first_name = "Dilermando"  #==> str
last_name = "Piva Jr."     #==> str
country = "Brazil"         #==> str
phone_number = 999999999   #==> int
weight = 89.2              #==> float
married = True             #==> bool

# %%
text = "Olá! Como você está?"
age = 22
type(age)
# Out:
# int

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
print(type(text))
# Out:
# <class 'str'>

# %%
number = 123
type(number)
# Out:
# int

# %%
decimal_number = 0.3333
type(decimal_number)
# Out:
# float

# %%
boolean = True
type(boolean)
# Out:
# bool

# %% [markdown]
# **FIM**
